# %%
import pandas as pd 
import folium
import requests
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Utility functions

# %%
def preprocess_data_per_year(data,df_department,year):
    # Get data relative to the year entered
    df_elec=data.loc[data["Année"]==year]
    # Remove dupplicate values for columns ...
    df_elec.drop_duplicates(subset=['Code INSEE de la commune'],inplace=True)
    # Drop missing values 
    df_elec.dropna(subset=['Code INSEE de la commune', 'Consommation annuelle moyenne de la commune (MWh)', 'Nom de la commune'],inplace=True)
    df_elec.rename(columns={'Code INSEE de la commune': 'code_commune_INSEE'}, inplace=True)
    df_elec['code_commune_INSEE']=df_elec['code_commune_INSEE'].astype(str)
    INSEE_codes=set(df_elec['code_commune_INSEE'])
    df_department=df_department.loc[df_department['code_commune_INSEE'].isin(INSEE_codes)]
    df_department['code_commune_INSEE']=df_department['code_commune_INSEE'].astype(int)
    df_elec['code_commune_INSEE']=df_elec['code_commune_INSEE'].astype(int)
    # Merging the two dataframes
    df_elec_department=pd.merge(df_department, df_elec, how='inner', on='code_commune_INSEE')
    df_elec_department.drop_duplicates(subset=['Consommation annuelle moyenne de la commune (MWh)', 'Nom de la commune', 'nom_departement'],inplace=True)
    df_elec_department.dropna(subset=[ 'Nom de la commune'],inplace=True)
    df_elec_department=df_elec_department[['Consommation annuelle moyenne de la commune (MWh)', 'Nom de la commune', 'nom_departement']]
    df_elec_department=df_elec_department.groupby(['nom_departement']).sum()
    return df_elec_department

# %% [markdown]
# # Importing data (for year 2018 only)

# %%
df_department=pd.read_csv("communes-departement-region.csv")
data= pd.read_csv('datamap.csv',  sep=';')

# %%
for year in range(2018,2022): 
    data_year=preprocess_data_per_year(data, df_department,year)
    cons[str(year)] =data_year["Consommation annuelle moyenne de la commune (MWh)"].values
df_cons_per_depart=pd.DataFrame(cons)
df_cons_per_depart["departement"]=data_year.index.values
df_cons_per_depart['avg_consumption'] = df_cons_per_depart.mean(axis=1)

# %%
df_cons_per_depart[['departement','avg_consumption']].to_csv("data_final.csv", index=False)

# %% [markdown]
# ## Electricity consumption data

# %%
df_elec=data.loc[df_elec["Année"]==year]
print("Number of lines", df_elec["Année"].count())
df_elec.head()
# Out:
# Number of lines 391099
#        Année  Code IRIS                            Nom IRIS  Numéro de voie  \
# 22809   2018  915890103                          Quartier 3             2.0
# 22810   2018  915890103                          Quartier 3             1.0
# 22811   2018  627850000  Savy-Berlette (commune non irisée)            19.0
# 22812   2018  920710108                 Musiciens-Roosevelt            11.0
# 22813   2018  920710105                 Desgranges-Fontenay             2.0
#
#       Indice de répétition Type de voie Libellé de voie  \
# 22809                  NaN          RUE        VAN GOGH
# 22810                  NaN          RUE        VAN GOGH
# 22811                  NaN          RUE     DES MANOIRS
# 22812                  NaN       AVENUE          CARNOT
# 22813                  NaN       SQUARE        D ALSACE
#
#        Code INSEE de la commune Nom de la commune Segment de client  \
# 22809                     91589  SAVIGNY-SUR-ORGE       RESIDENTIEL
# 22810                     91589  SAVIGNY-SUR-ORGE       RESIDENTIEL
# 22811                     62785     SAVY-BERLETTE       RESIDENTIEL
# 22812                     92071            SCEAUX       RESIDENTIEL
# 22813                     92071            SCEAUX       RESIDENTIEL
#
#        Nombre de logements  Consommation annuelle totale de l'adresse (MWh)  \
# 22809                   27                                           53.849
# 22810                   56                                          107.966
# 22811                   23                                          149.449
# 22812                   10                                           55.877
# 22813                   10                                           23.071
#
#        Consommation annuelle moyenne par logement de l'adresse (MWh)  \
# 22809                                              1.994
# 22810                                              1.928
# 22811                                              6.498
# 22812                                              5.588
# 22813                                              2.307
#
#        Consommation annuelle moyenne de la commune (MWh)             Adresse  \
# 22809                                              4.145      2 RUE VAN GOGH
# 22810                                              4.145      1 RUE VAN GOGH
# 22811                                              6.666  19 RUE DES MANOIRS
# 22812                                              3.788    11 AVENUE CARNOT
# 22813                                              3.788   2 SQUARE D ALSACE
#
#        Tri des adresses
# 22809            740012
# 22810            740013
# 22811            740018
# 22812            740047
# 22813            740059

# %%
# Remove dupplicate values for columns ...
df_elec.drop_duplicates(subset=['Code INSEE de la commune'],inplace=True)
# Drop missing values 
df_elec.dropna(subset=['Code INSEE de la commune', 'Consommation annuelle moyenne de la commune (MWh)', 'Nom de la commune'],inplace=True)

# %%
df_elec.count()
# Out:
# Année                                                            6160
# Code IRIS                                                        6160
# Nom IRIS                                                         6160
# Numéro de voie                                                   6160
# Indice de répétition                                              349
# Type de voie                                                     6024
# Libellé de voie                                                  6160
# Code INSEE de la commune                                         6160
# Nom de la commune                                                6160
# Segment de client                                                6160
# Nombre de logements                                              6160
# Consommation annuelle totale de l'adresse (MWh)                  6160
# Consommation annuelle moyenne par logement de l'adresse (MWh)    6160
# Consommation annuelle moyenne de la commune (MWh)                6160
# Adresse                                                          6160
# Tri des adresses                                                 6160
# dtype: int64

# %%
df_elec.rename(columns={'Code INSEE de la commune': 'code_commune_INSEE'}, inplace=True)
df_elec['code_commune_INSEE']=df_elec['code_commune_INSEE'].astype(str)
INSEE_codes=set(df_elec['code_commune_INSEE'])
df_elec.head()
# Out:
#        Année  Code IRIS                            Nom IRIS  Numéro de voie  \
# 22809   2018  915890103                          Quartier 3             2.0
# 22811   2018  627850000  Savy-Berlette (commune non irisée)            19.0
# 22812   2018  920710108                 Musiciens-Roosevelt            11.0
# 22857   2018  674450000    Scherwiller (commune non irisée)             8.0
# 22858   2018  742630000          Sciez (commune non irisée)           524.0
#
#       Indice de répétition Type de voie Libellé de voie code_commune_INSEE  \
# 22809                  NaN          RUE        VAN GOGH              91589
# 22811                  NaN          RUE     DES MANOIRS              62785
# 22812                  NaN       AVENUE          CARNOT              92071
# 22857                    C          RUE     DE SELESTAT              67445
# 22858                  NaN       AVENUE   DE BONNATRAIT              74263
#
#       Nom de la commune Segment de client  Nombre de logements  \
# 22809  SAVIGNY-SUR-ORGE       RESIDENTIEL                   27
# 22811     SAVY-BERLETTE       RESIDENTIEL                   23
# 22812            SCEAUX       RESIDENTIEL                   10
# 22857       SCHERWILLER       RESIDENTIEL                   10
# 22858             SCIEZ       RESIDENTIEL                   25
#
#        Consommation annuelle totale de l'adresse (MWh)  \
# 22809                                           53.849
# 22811                                          149.449
# 22812                                           55.877
# 22857                                           13.849
# 22858                                           45.248
#
#        Consommation annuelle moyenne par logement de l'adresse (MWh)  \
# 22809                                              1.994
# 22811                                              6.498
# 22812                                              5.588
# 22857                                              1.385
# 22858                                              1.810
#
#        Consommation annuelle moyenne de la commune (MWh)  \
# 22809                                              4.145
# 22811                                              6.666
# 22812                                              3.788
# 22857                                              5.382
# 22858                                              6.308
#
#                         Adresse  Tri des adresses
# 22809            2 RUE VAN GOGH            740012
# 22811        19 RUE DES MANOIRS            740018
# 22812          11 AVENUE CARNOT            740047
# 22857       8 C RUE DE SELESTAT            740320
# 22858  524 AVENUE DE BONNATRAIT            740326

# %% [markdown]
# ## Electricity consumption per department

# %%
# Importing data
df_department=pd.read_csv("communes-departement-region.csv")
df_department=df_department.loc[df_department['code_commune_INSEE'].isin(INSEE_codes)]
df_department['code_commune_INSEE']=df_department['code_commune_INSEE'].astype(int)
df_elec['code_commune_INSEE']=df_elec['code_commune_INSEE'].astype(int)
df_department.head()
# Out:
#     code_commune_INSEE nom_commune_postal  code_postal libelle_acheminement  \
# 2                 1004  AMBERIEU EN BUGEY         1500    AMBERIEU EN BUGEY
# 5                 1007           AMBRONAY         1500             AMBRONAY
# 8                 1010          ANGLEFORT         1350            ANGLEFORT
# 12                1014             ARBENT         1100               ARBENT
# 21                1024           ATTIGNAT         1340             ATTIGNAT
#
#    ligne_5   latitude  longitude  code_commune article        nom_commune  \
# 2      NaN  45.960848   5.372926           4.0     NaN  Ambérieu-en-Bugey
# 5      NaN  46.005591   5.357607           7.0     NaN           Ambronay
# 8      NaN  45.909372   5.795160          10.0     NaN          Anglefort
# 12     NaN  46.283494   5.690617          14.0     NaN             Arbent
# 21     NaN  46.286180   5.179523          24.0     NaN           Attignat
#
#    nom_commune_complet code_departement nom_departement  code_region  \
# 2    Ambérieu-en-Bugey                1             Ain         84.0
# 5             Ambronay                1             Ain         84.0
# 8            Anglefort                1             Ain         84.0
# 12              Arbent                1             Ain         84.0
# 21            Attignat                1             Ain         84.0
#
#               nom_region
# 2   Auvergne-Rhône-Alpes
# 5   Auvergne-Rhône-Alpes
# 8   Auvergne-Rhône-Alpes
# 12  Auvergne-Rhône-Alpes
# 21  Auvergne-Rhône-Alpes

# %%
# Merging the two dataframes
df_elec_department=pd.merge(df_department, df_elec, how='inner', on='code_commune_INSEE')
df_elec_department.drop_duplicates(subset=['Consommation annuelle moyenne de la commune (MWh)', 'Nom de la commune', 'nom_departement'],inplace=True)
df_elec_department.dropna(subset=[ 'Nom de la commune'],inplace=True)

# %%
df_elec_department=df_elec_department[['Consommation annuelle moyenne de la commune (MWh)', 'Nom de la commune', 'nom_departement']]

# %%
df_elec_department.groupby(['nom_departement']).sum()
# Out:
#                          Consommation annuelle moyenne de la commune (MWh)
# nom_departement
# Ain                                                                806.270
# Aisne                                                              354.479
# Allier                                                             148.999
# Alpes-Maritimes                                                    512.908
# Alpes-de-Haute-Provence                                            157.925
# ...                                                                    ...
# Vendée                                                             265.122
# Vienne                                                              88.716
# Vosges                                                             305.399
# Yonne                                                              180.799
# Yvelines                                                           863.520
#
# [93 rows x 1 columns]

# %% [markdown]
# ## Electricity consumption per year

# %%
data_2019=preprocess_data_per_year(data, df_department,2019)

# %%
data_2019.head(
# Out:
# Empty DataFrame
# Columns: [Consommation annuelle moyenne de la commune (MWh), Nom de la commune, nom_departement]
# Index: []

# %% [markdown]
# READ the geojason data

# %%
geojson_url='https://raw.githubusercontent.com/python-visualization/folium/main/examples/data/world-countries.json'
response=requests.get(geojson_url)
geojson=response.json()
##geojson

# %% [markdown]
# Create folium choropleth map

# %%
M=folium.Map(location=[20,10],zoom_start=2)
folium.Choropleth(
    geo-data=geojson,data=map_data,columns=[indicator,'Nom de la commune'],
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 M=folium.Map(location=[20,10],zoom_start=2)
#
# NameError: name 'folium' is not defined
